# %%
from binance.client import Client
#바이낸스 클라이언트 패키지에서 client 라이브러리를 임포트함 
import pandas as pd

# %%
#test api_key
test_api_Key = "ni1RGarrqKhXFMnmqZt2EEbEJkpGDXs4AxHml3r7aevzg7uqUR1rTFbNngWiTOln"
test_secret_Key = "HqFm7zQNQPOEJdYMgLho7engJbah6FAH98Eqf607h467CB9RM9e6dHDytnQbKGgk"

# %%
client = Client(api_key = test_api_Key, api_secret = test_secret_Key, tld = "com", testnet = True)

# %%
client

# %%
all_orders = client.get_all_orders(symbol="BTCUSDT")
all_orders
# Out:
# [{'symbol': 'BTCUSDT',
#   'orderId': 7262883,
#   'orderListId': -1,
#   'clientOrderId': '3uqO3n5k51Uc1eBVeTbQO4',
#   'price': '0.00000000',
#   'origQty': '0.10000000',
#   'executedQty': '0.10000000',
#   'cummulativeQuoteQty': '5164.11474910',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'MARKET',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1708872060815,
#   'updateTime': 1708872060815,
#   'isWorking': True,
#   'workingTime': 1708872060815,
#   'origQuoteOrderQty': '0.00000000',
#   'selfTradePreventionMode': 'EXPIRE_MAKER'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 7298460,
#   'orderListId': -1,
#   'clientOrderId': 'R14OoQSEysczXBDeiF9sd8',
#   'price': '0.00000000',
#   'origQty': '0.01938000',
#   'executedQty': '0.01938000',
#   'cummulativeQuoteQty': '999.92181390',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'MARKET',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1708878202243,
#   'updateTime': 1708878202243,
#   'isWorking': True,
#   'workingTime': 1708878202243,
#   'origQuoteOrderQty': '1000.00000000',
#   'selfTradePreventionMode': 'EXPIRE_MAKER'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 7311784,
#   'orderListId': -1,
#   'clientOrderId': 'vnTSrxpGrnHLz8IYpjPgng',
#   'price': '0.00000000',
#   'origQty': '0.10000000',
#   'executedQty': '0.10000000',
#   'cummulativeQuoteQty': '5138.67190420',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'MARKET',
#   'side': 'SELL',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1708880715888,
#   'updateTime': 1708880715888,
#   'isWorking': True,
#   'workingTime': 1708880715888,
#   'origQuoteOrderQty': '0.00000000',
#   'selfTradePreventionMode': 'EXPIRE_MAKER'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 7314089,
#   'orderListId': -1,
#   'clientOrderId': '02ZPkoFzioLsraxc63MeAq',
#   'price': '50000.00000000',
#   'origQty': '0.10000000',
#   'executedQty': '0.10000000',
#   'cummulativeQuoteQty': '5000.00000000',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1708881907316,
#   'updateTime': 1708885381195,
#   'isWorking': True,
#   'workingTime': 1708881907316,
#   'origQuoteOrderQty': '0.00000000',
#   'selfTradePreventionMode': 'EXPIRE_MAKER'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 7328016,
#   'orderListId': -1,
#   'clientOrderId': 'duURs6RQgqoT7kebtint0M',
#   'price': '50000.00000000',
#   'origQty': '0.00010000',
#   'executedQty': '0.00010000',
#   'cummulativeQuoteQty': '5.00000000',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1708884223377,
#   'updateTime': 1708885381195,
#   'isWorking': True,
#   'workingTime': 1708884223377,
#   'origQuoteOrderQty': '0.00000000',
#   'selfTradePreventionMode': 'EXPIRE_MAKER'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 7329614,
#   'orderListId': -1,
#   'clientOrderId': 'QzFDjnpJzIFVdQlX54mCsG',
#   'price': '50000.00000000',
#   'origQty': '0.00010000',
#   'executedQty': '0.00000000',
#   'cummulativeQuoteQty': '0.00000000',
#   'status': 'CANCELED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1708884489559,
#   'updateTime': 1708885305563,
#   'isWorking': True,
#   'workingTime': 1708884489559,
#   'origQuoteOrderQty': '0.00000000',
#   'selfTradePreventionMode': 'EXPIRE_MAKER'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 7333244,
#   'orderListId': -1,
#   'clientOrderId': 'KWi74wfzrYeP35oNpzX8sg',
#   'price': '50000.00000000',
#   'origQty': '0.00010000',
#   'executedQty': '0.00010000',
#   'cummulativeQuoteQty': '5.15310400',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'SELL',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1708885156960,
#   'updateTime': 1708885156960,
#   'isWorking': True,
#   'workingTime': 1708885156960,
#   'origQuoteOrderQty': '0.00000000',
#   'selfTradePreventionMode': 'EXPIRE_MAKER'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 7336362,
#   'orderListId': -1,
#   'clientOrderId': 'CyCfjtp4v3owCT07MWWs8I',
#   'price': '50000.00000000',
#   'origQty': '0.00010000',
#   'executedQty': '0.00000000',
#   'cummulativeQuoteQty': '0.00000000',
#   'status': 'CANCELED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1708885616615,
#   'updateTime': 1708885714598,
#   'isWorking': True,
#   'workingTime': 1708885616615,
#   'origQuoteOrderQty': '0.00000000',
#   'selfTradePreventionMode': 'EXPIRE_MAKER'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 7336386,
#   'orderListId': -1,
#   'clientOrderId': 'eW5XAqlXEzBj5TD0kI0fRb',
#   'price': '50000.00000000',
#   'origQty': '0.00010000',
#   'executedQty': '0.00010000',
#   'cummulativeQuoteQty': '5.15360100',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'SELL',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1708885620674,
#   'updateTime': 1708885620674,
#   'isWorking': True,
#   'workingTime': 1708885620674,
#   'origQuoteOrderQty': '0.00000000',
#   'selfTradePreventionMode': 'EXPIRE_MAKER'},
#  {'symbol': 'BTCUSDT',
#   'orderId': 7336865,
#   'orderListId': -1,
#   'clientOrderId': '1adUL57sWYHnQjg9eMGlbj',
#   'price': '60000.00000000',
#   'origQty': '0.00010000',
#   'executedQty': '0.00000000',
#   'cummulativeQuoteQty': '0.00000000',
#   'status': 'CANCELED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'SELL',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1708885699011,
#   'updateTime': 1708885731335,
#   'isWorking': True,
#   'workingTime': 1708885699011,
#   'origQuoteOrderQty': '0.00000000',
#   'selfTradePreventionMode': 'EXPIRE_MAKER'}]

# %%
pd.DataFrame(all_orders)
# Out:
#     symbol  orderId  orderListId           clientOrderId           price  \
# 0  BTCUSDT  7262883           -1  3uqO3n5k51Uc1eBVeTbQO4      0.00000000
# 1  BTCUSDT  7298460           -1  R14OoQSEysczXBDeiF9sd8      0.00000000
# 2  BTCUSDT  7311784           -1  vnTSrxpGrnHLz8IYpjPgng      0.00000000
# 3  BTCUSDT  7314089           -1  02ZPkoFzioLsraxc63MeAq  50000.00000000
# 4  BTCUSDT  7328016           -1  duURs6RQgqoT7kebtint0M  50000.00000000
# 5  BTCUSDT  7329614           -1  QzFDjnpJzIFVdQlX54mCsG  50000.00000000
# 6  BTCUSDT  7333244           -1  KWi74wfzrYeP35oNpzX8sg  50000.00000000
# 7  BTCUSDT  7336362           -1  CyCfjtp4v3owCT07MWWs8I  50000.00000000
# 8  BTCUSDT  7336386           -1  eW5XAqlXEzBj5TD0kI0fRb  50000.00000000
# 9  BTCUSDT  7336865           -1  1adUL57sWYHnQjg9eMGlbj  60000.00000000
#
#       origQty executedQty cummulativeQuoteQty    status timeInForce    type  \
# 0  0.10000000  0.10000000       5164.11474910    FILLED         GTC  MARKET
# 1  0.01938000  0.01938000        999.92181390    FILLED         GTC  MARKET
# 2  0.10000000  0.10000000       5138.67190420    FILLED         GTC  MARKET
# 3  0.10000000  0.10000000       5000.00000000    FILLED         GTC   LIMIT
# 4  0.00010000  0.00010000          5.00000000    FILLED         GTC   LIMIT
# 5  0.00010000  0.00000000          0.00000000  CANCELED         GTC   LIMIT
# 6  0.00010000  0.00010000          5.15310400    FILLED         GTC   LIMIT
# 7  0.00010000  0.00000000          0.00000000  CANCELED         GTC   LIMIT
# 8  0.00010000  0.00010000          5.15360100    FILLED         GTC   LIMIT
# 9  0.00010000  0.00000000          0.00000000  CANCELED         GTC   LIMIT
#
#    side   stopPrice  icebergQty           time     updateTime  isWorking  \
# 0   BUY  0.00000000  0.00000000  1708872060815  1708872060815       True
# 1   BUY  0.00000000  0.00000000  1708878202243  1708878202243       True
# 2  SELL  0.00000000  0.00000000  1708880715888  1708880715888       True
# 3   BUY  0.00000000  0.00000000  1708881907316  1708885381195       True
# 4   BUY  0.00000000  0.00000000  1708884223377  1708885381195       True
# 5   BUY  0.00000000  0.00000000  1708884489559  1708885305563       True
# 6  SELL  0.00000000  0.00000000  1708885156960  1708885156960       True
# 7   BUY  0.00000000  0.00000000  1708885616615  1708885714598       True
# 8  SELL  0.00000000  0.00000000  1708885620674  1708885620674       True
# 9  SELL  0.00000000  0.00000000  1708885699011  1708885731335       True
#
#      workingTime origQuoteOrderQty selfTradePreventionMode
# 0  1708872060815        0.00000000            EXPIRE_MAKER
# 1  1708878202243     1000.00000000            EXPIRE_MAKER
# 2  1708880715888        0.00000000            EXPIRE_MAKER
# 3  1708881907316        0.00000000            EXPIRE_MAKER
# 4  1708884223377        0.00000000            EXPIRE_MAKER
# 5  1708884489559        0.00000000            EXPIRE_MAKER
# 6  1708885156960        0.00000000            EXPIRE_MAKER
# 7  1708885616615        0.00000000            EXPIRE_MAKER
# 8  1708885620674        0.00000000            EXPIRE_MAKER
# 9  1708885699011        0.00000000            EXPIRE_MAKER

# %%
trades = client.get_my_trades(symbol="BTCUSDT")
trades
# Out:
# [{'symbol': 'BTCUSDT',
#   'id': 1375327,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51625.00000000',
#   'qty': '0.00185000',
#   'quoteQty': '95.50625000',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375328,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51625.91000000',
#   'qty': '0.00562000',
#   'quoteQty': '290.13761420',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375329,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51626.03000000',
#   'qty': '0.00840000',
#   'quoteQty': '433.65865200',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375330,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51626.14000000',
#   'qty': '0.00514000',
#   'quoteQty': '265.35835960',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375331,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51627.76000000',
#   'qty': '0.00891000',
#   'quoteQty': '460.00334160',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375332,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51627.95000000',
#   'qty': '0.00853000',
#   'quoteQty': '440.38641350',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375333,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51628.12000000',
#   'qty': '0.00659000',
#   'quoteQty': '340.22931080',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375334,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51629.05000000',
#   'qty': '0.00678000',
#   'quoteQty': '350.04495900',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375335,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51630.00000000',
#   'qty': '0.00640000',
#   'quoteQty': '330.43200000',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375336,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51630.46000000',
#   'qty': '0.00795000',
#   'quoteQty': '410.46215700',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375337,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51641.45000000',
#   'qty': '0.00756000',
#   'quoteQty': '390.40936200',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375338,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51641.52000000',
#   'qty': '0.00210000',
#   'quoteQty': '108.44719200',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375339,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51647.54000000',
#   'qty': '0.00523000',
#   'quoteQty': '270.11663420',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375340,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51650.93000000',
#   'qty': '0.00504000',
#   'quoteQty': '260.32068720',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375341,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51657.01000000',
#   'qty': '0.00210000',
#   'quoteQty': '108.47972100',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375342,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51672.51000000',
#   'qty': '0.00210000',
#   'quoteQty': '108.51227100',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375343,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51688.01000000',
#   'qty': '0.00210000',
#   'quoteQty': '108.54482100',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375344,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51703.52000000',
#   'qty': '0.00210000',
#   'quoteQty': '108.57739200',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375345,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51719.03000000',
#   'qty': '0.00210000',
#   'quoteQty': '108.60996300',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1375346,
#   'orderId': 7262883,
#   'orderListId': -1,
#   'price': '51728.72000000',
#   'qty': '0.00340000',
#   'quoteQty': '175.87764800',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708872060815,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1381053,
#   'orderId': 7298460,
#   'orderListId': -1,
#   'price': '51595.53000000',
#   'qty': '0.00650000',
#   'quoteQty': '335.37094500',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708878202243,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1381054,
#   'orderId': 7298460,
#   'orderListId': -1,
#   'price': '51595.56000000',
#   'qty': '0.00727000',
#   'quoteQty': '375.09972120',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708878202243,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1381055,
#   'orderId': 7298460,
#   'orderListId': -1,
#   'price': '51595.57000000',
#   'qty': '0.00561000',
#   'quoteQty': '289.45114770',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708878202243,
#   'isBuyer': True,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383533,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51391.12000000',
#   'qty': '0.00787000',
#   'quoteQty': '404.44811440',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383534,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51391.11000000',
#   'qty': '0.00857000',
#   'quoteQty': '440.42181270',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383535,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51390.81000000',
#   'qty': '0.00720000',
#   'quoteQty': '370.01383200',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383536,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51387.08000000',
#   'qty': '0.00758000',
#   'quoteQty': '389.51406640',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383537,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51387.07000000',
#   'qty': '0.00662000',
#   'quoteQty': '340.18240340',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383538,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51387.06000000',
#   'qty': '0.00052000',
#   'quoteQty': '26.72127120',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383539,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51387.04000000',
#   'qty': '0.00847000',
#   'quoteQty': '435.24822880',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383540,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51387.03000000',
#   'qty': '0.00974000',
#   'quoteQty': '500.50967220',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383541,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51386.77000000',
#   'qty': '0.00759000',
#   'quoteQty': '390.02558430',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383542,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51386.52000000',
#   'qty': '0.00954000',
#   'quoteQty': '490.22740080',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383543,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51386.17000000',
#   'qty': '0.00769000',
#   'quoteQty': '395.15964730',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383544,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51386.07000000',
#   'qty': '0.00506000',
#   'quoteQty': '260.01351420',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383545,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51379.07000000',
#   'qty': '0.00935000',
#   'quoteQty': '480.39430450',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1383546,
#   'orderId': 7311784,
#   'orderListId': -1,
#   'price': '51379.06000000',
#   'qty': '0.00420000',
#   'quoteQty': '215.79205200',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708880715888,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1385519,
#   'orderId': 7333244,
#   'orderListId': -1,
#   'price': '51531.04000000',
#   'qty': '0.00010000',
#   'quoteQty': '5.15310400',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708885156960,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1385679,
#   'orderId': 7314089,
#   'orderListId': -1,
#   'price': '50000.00000000',
#   'qty': '0.10000000',
#   'quoteQty': '5000.00000000',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708885381195,
#   'isBuyer': True,
#   'isMaker': True,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1385680,
#   'orderId': 7328016,
#   'orderListId': -1,
#   'price': '50000.00000000',
#   'qty': '0.00010000',
#   'quoteQty': '5.00000000',
#   'commission': '0.00000000',
#   'commissionAsset': 'BTC',
#   'time': 1708885381195,
#   'isBuyer': True,
#   'isMaker': True,
#   'isBestMatch': True},
#  {'symbol': 'BTCUSDT',
#   'id': 1386023,
#   'orderId': 7336386,
#   'orderListId': -1,
#   'price': '51536.01000000',
#   'qty': '0.00010000',
#   'quoteQty': '5.15360100',
#   'commission': '0.00000000',
#   'commissionAsset': 'USDT',
#   'time': 1708885620674,
#   'isBuyer': False,
#   'isMaker': False,
#   'isBestMatch': True}]

# %%
df = pd.DataFrame(trades)
df
# Out:
#      symbol       id  orderId  orderListId           price         qty  \
# 0   BTCUSDT  1375327  7262883           -1  51625.00000000  0.00185000
# 1   BTCUSDT  1375328  7262883           -1  51625.91000000  0.00562000
# 2   BTCUSDT  1375329  7262883           -1  51626.03000000  0.00840000
# 3   BTCUSDT  1375330  7262883           -1  51626.14000000  0.00514000
# 4   BTCUSDT  1375331  7262883           -1  51627.76000000  0.00891000
# 8    330.43200000  0.00000000             BTC  1708872060815     True
# 9    410.46215700  0.00000000             BTC  1708872060815     True
# 10   390.40936200  0.00000000             BTC  1708872060815     True
# 11   108.44719200  0.00000000             BTC  1708872060815     True
# 12   270.11663420  0.00000000             BTC  1708872060815     True
# 13   260.32068720  0.00000000             BTC  1708872060815     True
# 14   108.47972100  0.00000000             BTC  1708872060815     True
# 15   108.51227100  0.00000000             BTC  1708872060815     True
# 16   108.54482100  0.00000000             BTC  1708872060815     True
# 17   108.57739200  0.00000000             BTC  1708872060815     True
# 18   108.60996300  0.00000000             BTC  1708872060815     True
# 19   175.87764800  0.00000000             BTC  1708872060815     True
# 20   335.37094500  0.00000000             BTC  1708878202243     True
# 21   375.09972120  0.00000000             BTC  1708878202243     True
# 22   289.45114770  0.00000000             BTC  1708878202243     True
# 23   404.44811440  0.00000000            USDT  1708880715888    False
# 24   440.42181270  0.00000000            USDT  1708880715888    False
# 25   370.01383200  0.00000000            USDT  1708880715888    False
# 26   389.51406640  0.00000000            USDT  1708880715888    False
# 27   340.18240340  0.00000000            USDT  1708880715888    False
# 28    26.72127120  0.00000000            USDT  1708880715888    False
# 29   435.24822880  0.00000000            USDT  1708880715888    False
# 30   500.50967220  0.00000000            USDT  1708880715888    False
# 31   390.02558430  0.00000000            USDT  1708880715888    False
# 32   490.22740080  0.00000000            USDT  1708880715888    False
# 33   395.15964730  0.00000000            USDT  1708880715888    False
# 34   260.01351420  0.00000000            USDT  1708880715888    False
# 35   480.39430450  0.00000000            USDT  1708880715888    False
# 36   215.79205200  0.00000000            USDT  1708880715888    False
# 37     5.15310400  0.00000000            USDT  1708885156960    False
# 38  5000.00000000  0.00000000             BTC  1708885381195     True
# 39     5.00000000  0.00000000             BTC  1708885381195     True
# 40     5.15360100  0.00000000            USDT  1708885620674    False
#
#     isMaker  isBestMatch
# 0     False         True
# 1     False         True
# 2     False         True
# 3     False         True
# 4     False         True
# 5     False         True
# 6     False         True
# 7     False         True
# 8     False         True
# 9     False         True
# 10    False         True
# 11    False         True
# 12    False         True
# 13    False         True
# 14    False         True
# 15    False         True
# 16    False         True
# 17    False         True
# 18    False         True
# 19    False         True
# 20    False         True
# 21    False         True
# 22    False         True
# 23    False         True
# 24    False         True
# 25    False         True
# 26    False         True
# 27    False         True
# 28    False         True
# 29    False         True
# 30    False         True
# 31    False         True
# 32    False         True
# 33    False         True
# 34    False         True
# 35    False         True
# 36    False         True
# 37    False         True
# 38     True         True
# 39     True         True
# 40    False         True

# %%
df.time = pd.to_datetime(df.time, unit = "ms", errors = "coerce")

# %%
df
# Out:
#      symbol       id  orderId  orderListId           price         qty  \
# 0   BTCUSDT  1375327  7262883           -1  51625.00000000  0.00185000
# 1   BTCUSDT  1375328  7262883           -1  51625.91000000  0.00562000
# 2   BTCUSDT  1375329  7262883           -1  51626.03000000  0.00840000
# 3   BTCUSDT  1375330  7262883           -1  51626.14000000  0.00514000
# 4   BTCUSDT  1375331  7262883           -1  51627.76000000  0.00891000
# 5   BTCUSDT  1375332  7262883           -1  51627.95000000  0.00853000
# 6   BTCUSDT  1375333  7262883           -1  51628.12000000  0.00659000
# 9    410.46215700  0.00000000             BTC 2024-02-25 14:41:00.815
# 10   390.40936200  0.00000000             BTC 2024-02-25 14:41:00.815
# 11   108.44719200  0.00000000             BTC 2024-02-25 14:41:00.815
# 12   270.11663420  0.00000000             BTC 2024-02-25 14:41:00.815
# 13   260.32068720  0.00000000             BTC 2024-02-25 14:41:00.815
# 14   108.47972100  0.00000000             BTC 2024-02-25 14:41:00.815
# 15   108.51227100  0.00000000             BTC 2024-02-25 14:41:00.815
# 16   108.54482100  0.00000000             BTC 2024-02-25 14:41:00.815
# 17   108.57739200  0.00000000             BTC 2024-02-25 14:41:00.815
# 18   108.60996300  0.00000000             BTC 2024-02-25 14:41:00.815
# 19   175.87764800  0.00000000             BTC 2024-02-25 14:41:00.815
# 20   335.37094500  0.00000000             BTC 2024-02-25 16:23:22.243
# 21   375.09972120  0.00000000             BTC 2024-02-25 16:23:22.243
# 22   289.45114770  0.00000000             BTC 2024-02-25 16:23:22.243
# 23   404.44811440  0.00000000            USDT 2024-02-25 17:05:15.888
# 24   440.42181270  0.00000000            USDT 2024-02-25 17:05:15.888
# 25   370.01383200  0.00000000            USDT 2024-02-25 17:05:15.888
# 26   389.51406640  0.00000000            USDT 2024-02-25 17:05:15.888
# 27   340.18240340  0.00000000            USDT 2024-02-25 17:05:15.888
# 28    26.72127120  0.00000000            USDT 2024-02-25 17:05:15.888
# 29   435.24822880  0.00000000            USDT 2024-02-25 17:05:15.888
# 30   500.50967220  0.00000000            USDT 2024-02-25 17:05:15.888
# 31   390.02558430  0.00000000            USDT 2024-02-25 17:05:15.888
# 32   490.22740080  0.00000000            USDT 2024-02-25 17:05:15.888
# 33   395.15964730  0.00000000            USDT 2024-02-25 17:05:15.888
# 34   260.01351420  0.00000000            USDT 2024-02-25 17:05:15.888
# 35   480.39430450  0.00000000            USDT 2024-02-25 17:05:15.888
# 36   215.79205200  0.00000000            USDT 2024-02-25 17:05:15.888
# 37     5.15310400  0.00000000            USDT 2024-02-25 18:19:16.960
# 38  5000.00000000  0.00000000             BTC 2024-02-25 18:23:01.195
# 39     5.00000000  0.00000000             BTC 2024-02-25 18:23:01.195
# 40     5.15360100  0.00000000            USDT 2024-02-25 18:27:00.674
#
#     isBuyer  isMaker  isBestMatch
# 0      True    False         True
# 1      True    False         True
# 2      True    False         True
# 3      True    False         True
# 4      True    False         True
# 5      True    False         True
# 6      True    False         True
# 7      True    False         True
# 8      True    False         True
# 9      True    False         True
# 10     True    False         True
# 11     True    False         True
# 12     True    False         True
# 13     True    False         True
# 14     True    False         True
# 15     True    False         True
# 16     True    False         True
# 17     True    False         True
# 18     True    False         True
# 19     True    False         True
# 20     True    False         True
# 21     True    False         True
# 22     True    False         True
# 23    False    False         True
# 24    False    False         True
# 25    False    False         True
# 26    False    False         True
# 27    False    False         True
# 28    False    False         True
# 29    False    False         True
# 30    False    False         True
# 31    False    False         True
# 32    False    False         True
# 33    False    False         True
# 34    False    False         True
# 35    False    False         True
# 36    False    False         True
# 37    False    False         True
# 38     True     True         True
# 39     True     True         True
# 40    False    False         True
