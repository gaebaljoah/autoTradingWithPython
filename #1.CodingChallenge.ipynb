# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn-v0_8")

# %%
start = "2015-01-02"
end = "2024-03-04"
symbol = ["GE","Reliance.NS"]
#야후 파이낸스에서 미국이 아닌 다른 나라의 티거들은 해당나라의 접미사를 붙혀야한다.

# %%
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Price      Adj Close                Close                 High              \
# Ticker            GE RELIANCE.NS       GE RELIANCE.NS       GE RELIANCE.NS
# Date
# 2015-01-02  130.1179    381.7990 150.4834    404.8437 152.8854    409.6439
# 2015-01-05  127.7295    377.6169 147.7211    400.4091 150.1832    407.2895
# 2015-01-06  124.9776    360.4789 144.5385    382.2368 147.5410    399.1062
# 2015-01-07  125.0295    368.3258 144.5986    390.5572 146.4601    392.6145
# 2015-01-08  126.5353    363.0443 146.3400    384.9569 146.4001    394.4889
# ...              ...         ...      ...         ...      ...         ...
# 2024-02-26  154.7700   2974.6499 154.7700   2974.6499 155.1800   2989.0500
# 2024-02-27  153.9900   2971.3000 153.9900   2971.3000 155.0100   2999.8999
# 2024-02-28  155.6100   2911.2500 155.6100   2911.2500 156.9100   2982.5500
# 2024-02-29  156.8900   2921.6001 156.8900   2921.6001 157.1800   2957.9500
# 2024-03-01  158.6500   2984.2500 158.6500   2984.2500 159.3200   3000.0000
#
# Price           Low                 Open                    Volume  \
# Ticker           GE RELIANCE.NS       GE RELIANCE.NS            GE
# Date
# 2015-01-02 149.3425    404.2722 152.1648    406.0094  6814541.0000
# 2015-01-05 147.2407    399.6091 150.1832    404.5922  6999789.0000
# 2015-01-06 143.6978    380.3624 146.8804    397.7347 10617953.0000
# 2015-01-07 143.9981    382.6483 145.3792    382.6940  7267786.0000
# 2015-01-08 144.8988    384.0883 146.0397    393.2088  7198159.0000
# ...             ...         ...      ...         ...           ...
# 2024-02-26 153.5600   2965.0000 153.6600   2987.1001  6149600.0000
# 2024-02-27 153.1000   2956.1001 154.9900   2966.0500  5826300.0000
# 2024-02-28 153.8200   2900.3501 154.1600   2966.0000  6091800.0000
# 2024-02-29 155.1000   2909.0500 155.9900   2930.0000  6526200.0000
# 2024-03-01 156.8700   2925.0000 157.0000   2927.0000  6937200.0000
#
# Price
# Ticker       RELIANCE.NS
# Date
# 2015-01-02  3665683.0000
# 2015-01-05  5051970.0000
# 2015-01-06  9313990.0000
# 2015-01-07 10360156.0000
# 2015-01-08  9936113.0000
# ...                  ...
# 2024-02-26  3756553.0000
# 2024-02-27  5413022.0000
# 2024-02-28  4323975.0000
# 2024-02-29 11814488.0000
# 2024-03-01  6066463.0000
#
# [2375 rows x 12 columns]

# %%
close = df.Close.copy()
close
# Out:
# Ticker           GE  RELIANCE.NS
# Date
# 2015-01-02 150.4834     404.8437
# 2015-01-05 147.7211     400.4091
# 2015-01-06 144.5385     382.2368
# 2015-01-07 144.5986     390.5572
# 2015-01-08 146.3400     384.9569
# ...             ...          ...
# 2024-02-26 154.7700    2974.6499
# 2024-02-27 153.9900    2971.3000
# 2024-02-28 155.6100    2911.2500
# 2024-02-29 156.8900    2921.6001
# 2024-03-01 158.6500    2984.2500
#
# [2375 rows x 2 columns]

# %%
close.GE.dropna().plot(figsize = (15,8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
norm = close.div(close.iloc[0]).mul(1)

# %%
norm
# Out:
# Ticker         GE  RELIANCE.NS
# Date
# 2015-01-02 1.0000       1.0000
# 2015-01-05 0.9816       0.9890
# 2015-01-06 0.9605       0.9442
# 2015-01-07 0.9609       0.9647
# 2015-01-08 0.9725       0.9509
# ...           ...          ...
# 2024-02-26 1.0285       7.3477
# 2024-02-27 1.0233       7.3394
# 2024-02-28 1.0341       7.1910
# 2024-02-29 1.0426       7.2166
# 2024-03-01 1.0543       7.3714
#
# [2375 rows x 2 columns]

# %%
norm.dropna().plot(figsize = (15,8), fontsize = 13, logy = True)
plt.legend(fontsize = 13)
plt.show()
