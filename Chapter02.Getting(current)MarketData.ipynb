# %% [markdown]
# ### 시장 정보 데이터 가져오기
# ###### 비트코인의 가장 퇴근 미국 달러 가격 또는 유로 가격등을 알 수 있다.

# %%
api_key = "TGV2OZgIKqiCEWvhVUAUDGBB99Eixo1z2ILlZ0h3lRdutfklTwRlqzPYpIazsYcn"
secret_key = "CrgLtKo6MRxdL6tJRNKokKPKOAWa0Rn59Q9KfX57yal0E1WTqz79jk2IT03g6VcZ"

# %%
from binance.client import Client
import pandas as pd

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com")
client

# %% [markdown]
# #### Current Prices

# %%
client.get_symbol_ticker(symbol = "BTCUSDT") #current price for one symbol
# Out:
# {'symbol': 'BTCUSDT', 'price': '43163.44000000'}

# %%
float(client.get_symbol_ticker(symbol = "BTCEUR")["price"]) #실수로 변경하기
# Out:
# 39688.32

# %%
client.get_avg_price(symbol = "BTCUSDT") #current average price #5분동안의 평균 가격이 나옴 closeTime은 유닉스 시간
# Out:
# {'mins': 5, 'price': '43172.05536862', 'closeTime': 1706877591719}

# %%
#get current prices for all pairs
prices = client.get_all_tickers()
prices
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.05365000'},
#  {'symbol': 'LTCBTC', 'price': '0.00157300'},
#  {'symbol': 'BNBBTC', 'price': '0.00700500'},
#  {'symbol': 'NEOBTC', 'price': '0.00025550'},
#  {'symbol': 'QTUMETH', 'price': '0.00124100'},
#  {'symbol': 'EOSETH', 'price': '0.00030420'},
#  {'symbol': 'SNTETH', 'price': '0.00001669'},
#  {'symbol': 'BNTETH', 'price': '0.00031070'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00013250'},
#  {'symbol': 'BNBETH', 'price': '0.13060000'},
#  {'symbol': 'BTCUSDT', 'price': '43163.44000000'},
#  {'symbol': 'ETHUSDT', 'price': '2315.51000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00000024'},
# ...

# %%
df = pd.DataFrame(prices)
df
# Out:
#          symbol        price
# 0        ETHBTC   0.05365000
# 1        LTCBTC   0.00157300
# 2        BNBBTC   0.00700500
# 3        NEOBTC   0.00025550
# 4       QTUMETH   0.00124100
# ...         ...          ...
# 2461    SEIUSDC   0.64260000
# 2462    PYTHBTC   0.00001159
# 2463   PYTHUSDT   0.49940000
# 2464  PYTHFDUSD   0.50040000
# 2465    PYTHTRY  15.28000000
#
# [2466 rows x 2 columns]

# %%
df[df.symbol.str.contains("ETH")] #이더리움 문자열을 포함하고 있는 코인 가격
# Out:
#         symbol          price
# 0       ETHBTC     0.05365000
# 4      QTUMETH     0.00124100
# 5       EOSETH     0.00030420
# 6       SNTETH     0.00001669
# 7       BNTETH     0.00031070
# ...        ...            ...
# 2269  ETHFDUSD  2316.14000000
# 2295  CYBERETH     0.00304600
# 2342    INJETH     0.01503000
# 2378   ETHAEUR  2125.62000000
# 2392   MEMEETH     0.00000954
#
# [258 rows x 2 columns]

# %%
df[df.symbol.str.contains("BTC") & df.symbol.str.contains("USD")]
# Out:
#            symbol           price
# 11        BTCUSDT  43163.44000000
# 312       BTCTUSD  43724.45000000
# 313       TUSDBTC      0.00025971
# 417       BTCUSDC  43144.00000000
# 454       BTCUSDS   9604.59000000
# 614       BTCBUSD  42769.40000000
# 795     BTCUPUSDT     10.21700000
# 796   BTCDOWNUSDT      0.00235100
# 1190      SUSDBTC      0.00002065
# 1240    BTCSTBUSD      1.16000000
# 1241    BTCSTUSDT      5.35000000
# 1621      BTCUSDP  19435.03000000
# 2070     WBTCBUSD  40760.13000000
# 2198     WBTCUSDT  43111.70000000
# 2268     BTCFDUSD  43172.78000000

# %%
last24 = client.get_ticker(symbol = "BTCUSDT") # 24H Price change statistic #최근 24시간 변동내역 
last24
# Out:
# {'symbol': 'BTCUSDT',
#  'priceChange': '980.28000000',
#  'priceChangePercent': '2.324',
#  'weightedAvgPrice': '42921.49666907',
#  'prevClosePrice': '42183.16000000',
#  'lastPrice': '43163.45000000',
#  'lastQty': '0.00049000',
#  'bidPrice': '43163.44000000',
#  'bidQty': '0.54424000',
#  'askPrice': '43163.45000000',
#  'askQty': '16.11300000',
#  'openPrice': '42183.17000000',
#  'highPrice': '43432.63000000',
#  'lowPrice': '41981.17000000',
#  'volume': '32524.43875000',
#  'quoteVolume': '1395997589.47160100',
#  'openTime': 1706791192076,
#  'closeTime': 1706877592076,
#  'firstId': 3397966138,
#  'lastId': 3399159320,
#  'count': 1193183}

# %%
last24["openTime"] #유닉스 시간
# Out:
# 1706791192076

# %%
pd.to_datetime(last24["openTime"], unit="ms")
# Out:
# Timestamp('2024-02-01 12:39:52.076000')

# %%
pd.to_datetime(last24["closeTime"], unit="ms")
# Out:
# Timestamp('2024-02-02 12:39:52.076000')

# %%
open_price = float(last24["openPrice"])
open_price
# Out:
# 42183.17

# %%
high_price = float(last24["highPrice"])
high_price
# Out:
# 43432.63

# %%
low_price = float(last24["lowPrice"])
low_price
# Out:
# 41981.17

# %%
close_price = float(last24["lastPrice"])
close_price
# Out:
# 43163.45

# %%
close_price - open_price #종가와 시가의 차이
# Out:
# 980.2799999999988

# %%
(close_price/open_price -1) * 100  #최근 가격추세 last24 json데이터의 priceChangePercent와 동일
# Out:
# 2.3238651813033417
