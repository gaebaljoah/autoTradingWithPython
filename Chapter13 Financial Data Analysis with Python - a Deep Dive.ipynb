# %% [markdown]
# ### **Installing required Libraries/Packages**
# 야후 파이낸스 사용하기
# use anaconda prompt
# ###### install yfinance with :
# - pip install yfinance
#
# (first : conda update anaconda)

# %% [markdown]
# ### Loading Financial Data from the Web

# %%
import pandas as pd 
import yfinance as yf

# %%
start = "2014-10-01"
end = "2024-03-13"

# %%
symbol = "AMC"

# %%
yf.download(symbol, start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-10-01  230.000000  230.699997  227.600006  229.100006  167.649582
# 2014-10-02  228.600006  232.600006  224.500000  232.000000  169.771744
# 2014-10-03  233.600006  235.600006  231.000000  234.100006  171.308441
# 2014-10-06  234.199997  236.000000  232.100006  232.199997  169.918106
# 2014-10-07  231.800003  233.100006  224.500000  224.699997  164.429749
# ...                ...         ...         ...         ...         ...
# 2024-02-12    4.380000    4.720000    4.310000    4.560000    4.560000
# 2024-02-13    4.370000    4.680000    4.260000    4.490000    4.490000
# 2024-02-14    4.620000    4.870000    4.470000    4.800000    4.800000
# 2024-02-15    4.800000    5.050000    4.760000    4.890000    4.890000
# 2024-02-16    4.770000    4.950000    4.620000    4.830000    4.830000
#
#               Volume
# Date
# ...

# %%
df = yf.download(symbol, start, end)
df
#Adj Close => 배당금을 고려한 종가이다.
# Out:
# [*********************100%%**********************]  7 of 7 completed
# Price      Adj Close                                                           \
# Ticker           AMC       BA    BTC-USD EURUSD=X      GC=F     MSFT USDEUR=X
# Date
# 2014-01-01       NaN      NaN        NaN   1.3745       NaN      NaN   0.7275
# 2014-01-02  145.1402 116.8079        NaN   1.3767 1225.0000  31.2331   0.7264
# 2014-01-03  143.9895 117.6199        NaN   1.3667 1238.4000  31.0229   0.7317
# 2014-01-06  143.9175 118.2951        NaN   1.3596 1237.8000  30.3673   0.7355
# 2014-01-07  144.2053 120.0899        NaN   1.3632 1229.4000  30.6027   0.7336
# ...              ...      ...        ...      ...       ...      ...      ...
# 2024-03-08    4.3000 198.4900 68300.0938   1.0950 2178.6001 406.2200   0.9132
# 2024-03-09       NaN      NaN 68498.8828      NaN       NaN      NaN      NaN
# 2024-03-10       NaN      NaN 69019.7891      NaN       NaN      NaN      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2361 entries, 2014-10-01 to 2024-02-16
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2361 non-null   float64
#  1   High       2361 non-null   float64
#  2   Low        2361 non-null   float64
#  3   Close      2361 non-null   float64
#  4   Adj Close  2361 non-null   float64
#  5   Volume     2361 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 129.1 KB

# %%
symbol = ["AMC","BA","MSFT","BTC-USD","GC=F","EURUSD=X","USDEUR=X"]

# %%
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%%**********************]  7 of 7 completed
# Price      Adj Close                                                           \
# Ticker           AMC       BA    BTC-USD EURUSD=X      GC=F     MSFT USDEUR=X
# Date
# 2014-10-01  167.6496 108.4067   383.6150   1.2628 1214.6000  39.3870   0.7919
# 2014-10-02  169.7717 107.9719   375.0720   1.2624 1214.2000  39.2669   0.7921
# 2014-10-03  171.3084 109.8762   359.5120   1.2671 1192.2000  39.5501   0.7892
# 2014-10-04       NaN      NaN   328.8660      NaN       NaN      NaN      NaN
# 2014-10-05       NaN      NaN   320.5100      NaN       NaN      NaN      NaN
# ...              ...      ...        ...      ...       ...      ...      ...
# 2024-03-08    4.3000 198.4900 68300.0938   1.0950 2178.6001 406.2200   0.9132
# 2024-03-09       NaN      NaN 68498.8828      NaN       NaN      NaN      NaN
# 2024-03-10       NaN      NaN 69019.7891      NaN       NaN      NaN      NaN
# ...

# %%
df.to_csv("multi_assets_2024_03.csv")

# %% [markdown]
# ### **Initial Inspection and Visualization**
# #### 초기조사와 시각화

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn-v0_8")

# %%
pd.read_csv("multi_assets_2024_03.csv", header = [0,1], index_col = 0, parse_dates = [0])
# Out:
# Price      Adj Close                                                           \
# Ticker           AMC       BA    BTC-USD EURUSD=X      GC=F     MSFT USDEUR=X
# Date
# 2014-10-01  167.6496 108.4067   383.6150   1.2628 1214.6000  39.3870   0.7919
# 2014-10-02  169.7717 107.9719   375.0720   1.2624 1214.2000  39.2669   0.7921
# 2014-10-03  171.3084 109.8762   359.5120   1.2671 1192.2000  39.5501   0.7892
# 2014-10-04       NaN      NaN   328.8660      NaN       NaN      NaN      NaN
# 2014-10-05       NaN      NaN   320.5100      NaN       NaN      NaN      NaN
# ...              ...      ...        ...      ...       ...      ...      ...
# 2024-03-08    4.3000 198.4900 68300.0938   1.0950 2178.6001 406.2200   0.9132
# 2024-03-09       NaN      NaN 68498.8828      NaN       NaN      NaN      NaN
# 2024-03-10       NaN      NaN 69019.7891      NaN       NaN      NaN      NaN
# 2024-03-11    4.3600 192.4900 72123.9062   1.0943 2182.5000 404.5200   0.9138
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3451 entries, 2014-10-01 to 2024-03-12
# Freq: D
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, AMC)       2377 non-null   float64
#  1   (Adj Close, BA)        2377 non-null   float64
#  2   (Adj Close, BTC-USD)   3451 non-null   float64
#  3   (Adj Close, EURUSD=X)  2462 non-null   float64
#  4   (Adj Close, GC=F)      2376 non-null   float64
#  5   (Adj Close, MSFT)      2377 non-null   float64
#  6   (Adj Close, USDEUR=X)  2462 non-null   float64
#  7   (Close, AMC)           2377 non-null   float64
#  8   (Close, BA)            2377 non-null   float64
#  9   (Close, BTC-USD)       3451 non-null   float64
#  10  (Close, EURUSD=X)      2462 non-null   float64
#  11  (Close, GC=F)          2376 non-null   float64
#  12  (Close, MSFT)          2377 non-null   float64
# ...

# %%
df.Close # 종가만 확인하기
# Out:
# Ticker          AMC       BA    BTC-USD  EURUSD=X      GC=F     MSFT  USDEUR=X
# Date
# 2014-10-01 229.1000 124.6700   383.6150    1.2628 1214.6000  45.9000    0.7919
# 2014-10-02 232.0000 124.1700   375.0720    1.2624 1214.2000  45.7600    0.7921
# 2014-10-03 234.1000 126.3600   359.5120    1.2671 1192.2000  46.0900    0.7892
# 2014-10-04      NaN      NaN   328.8660       NaN       NaN      NaN       NaN
# 2014-10-05      NaN      NaN   320.5100       NaN       NaN      NaN       NaN
# ...             ...      ...        ...       ...       ...      ...       ...
# 2024-03-08   4.3000 198.4900 68300.0938    1.0950 2178.6001 406.2200    0.9132
# 2024-03-09      NaN      NaN 68498.8828       NaN       NaN      NaN       NaN
# 2024-03-10      NaN      NaN 69019.7891       NaN       NaN      NaN       NaN
# 2024-03-11   4.3600 192.4900 72123.9062    1.0943 2182.5000 404.5200    0.9138
# 2024-03-12   4.3400 184.2400 71481.2891    1.0931 2160.3999 415.2800    0.9148
#
# ...

# %%
df.Close.MSFT #MSFT의 종가 데이터만 가져오기
# Out:
# Date
# 2014-10-01    45.9000
# 2014-10-02    45.7600
# 2014-10-03    46.0900
# 2014-10-04        NaN
# 2014-10-05        NaN
#                ...
# 2024-03-08   406.2200
# 2024-03-09        NaN
# 2024-03-10        NaN
# 2024-03-11   404.5200
# 2024-03-12   415.2800
# Freq: D, Name: MSFT, Length: 3451, dtype: float64

# %%
#pandas의 loc메서드를 활용하여 데이터를 가져올 수도 있음.
#data.loc[row_label, column_label]
df.loc[:,"Close"] # Close열의 하위 열의 모든 내용을 가져옴
df.loc[:,("Close","MSFT")] #Close열의 MSFT 종가 내용을 가져옴
# Out:
# Date
# 2014-10-01    45.9000
# 2014-10-02    45.7600
# 2014-10-03    46.0900
# 2014-10-04        NaN
# 2014-10-05        NaN
#                ...
# 2024-03-08   406.2200
# 2024-03-09        NaN
# 2024-03-10        NaN
# 2024-03-11   404.5200
# 2024-03-12   415.2800
# Freq: D, Name: (Close, MSFT), Length: 3451, dtype: float64

# %%
df.loc["2015-01-08"] #onday/row
# Out:
# Price      Ticker
# Adj Close  AMC             190.4776
#            BA              115.2753
#            BTC-USD         283.3490
#            EURUSD=X          1.1836
#            GC=F           1208.4000
#            MSFT             41.0948
#            USDEUR=X          0.8449
# Close      AMC             258.3000
#            BA              131.8000
#            BTC-USD         283.3490
#            EURUSD=X          1.1836
#            GC=F           1208.4000
#            MSFT             47.5900
#            USDEUR=X          0.8449
# High       AMC             261.2000
#            BA              131.9900
#            BTC-USD         294.1350
#            EURUSD=X          1.1848
#            GC=F           1215.7000
#            MSFT             47.7500
#            USDEUR=X          0.8506
# Low        AMC             253.1000
#            BA              130.4000
#            BTC-USD         282.1750
#            EURUSD=X          1.1756
# ...

# %%
df.loc["2015"]
# Out:
# Price      Adj Close                                                        \
# Ticker           AMC       BA  BTC-USD EURUSD=X      GC=F    MSFT USDEUR=X
# Date
# 2015-01-01       NaN      NaN 314.2490   1.2099       NaN     NaN   0.8265
# 2015-01-02  189.0027 113.6572 315.0320   1.2089 1186.0000 40.3781   0.8272
# 2015-01-03       NaN      NaN 281.0820      NaN       NaN     NaN      NaN
# 2015-01-04       NaN      NaN 264.1950      NaN       NaN     NaN      NaN
# 2015-01-05  184.1357 112.8701 274.4740   1.1946 1203.9000 40.0068   0.8371
# ...              ...      ...      ...      ...       ...     ...      ...
# 2015-12-27       NaN      NaN 422.8230      NaN       NaN     NaN      NaN
# 2015-12-28  174.6616 129.6283 422.2790   1.0966 1070.5000 49.6291   0.9119
# 2015-12-29  177.7711 132.1484 432.9830   1.0975 1077.5000 50.1613   0.9111
# 2015-12-30  179.4396 131.3054 426.6200   1.0928 1060.1000 49.9484   0.9151
# ...

# %%
df.loc["2020-06",("Close", "AMC")] #힌딜동안의 amc종가
# Out:
# Date
# 2020-06-01   53.1000
# 2020-06-02   55.9000
# 2020-06-03   54.5000
# 2020-06-04   53.8000
# 2020-06-05   59.1000
# 2020-06-06       NaN
# 2020-06-07       NaN
# 2020-06-08   64.5000
# 2020-06-09   59.9000
# 2020-06-10   62.9000
# 2020-06-11   51.7000
# 2020-06-12   58.9000
# 2020-06-13       NaN
# 2020-06-14       NaN
# 2020-06-15   58.0000
# 2020-06-16   55.6000
# 2020-06-17   54.2000
# 2020-06-18   56.3000
# 2020-06-19   55.2000
# 2020-06-20       NaN
# 2020-06-21       NaN
# 2020-06-22   53.3000
# 2020-06-23   51.0000
# 2020-06-24   47.9000
# 2020-06-25   42.7000
# 2020-06-26   41.8000
# 2020-06-27       NaN
# 2020-06-28       NaN
# 2020-06-29   44.2000
# 2020-06-30   42.9000
# Freq: D, Name: (Close, AMC), dtype: float64

# %%
df = df.swaplevel(axis = "columns").sort_index(axis = "columns") 
# 상위 컬럼과 하위 컬럼의 위치를 서로 바꾸는 메서드 
df
# Out:
# Ticker           AMC                                                    \
# Price      Adj Close    Close     High      Low     Open        Volume
# Date
# 2014-10-01  167.6496 229.1000 230.7000 227.6000 230.0000    27330.0000
# 2014-10-02  169.7717 232.0000 232.6000 224.5000 228.6000    24310.0000
# 2014-10-03  171.3084 234.1000 235.6000 231.0000 233.6000     5770.0000
# 2014-10-04       NaN      NaN      NaN      NaN      NaN           NaN
# 2014-10-05       NaN      NaN      NaN      NaN      NaN           NaN
# ...              ...      ...      ...      ...      ...           ...
# 2024-03-08    4.3000   4.3000   4.7800   4.2400   4.6800 17458800.0000
# 2024-03-09       NaN      NaN      NaN      NaN      NaN           NaN
# 2024-03-10       NaN      NaN      NaN      NaN      NaN           NaN
# 2024-03-11    4.3600   4.3600   4.5000   4.2500   4.3000 12463000.0000
# 2024-03-12    4.3400   4.3400   4.4100   4.2700   4.3800  7131900.0000
#
# ...

# %%
df["BTC-USD"]
# Out:
# Price       Adj Close      Close       High        Low       Open       Volume
# Date
# 2014-10-01   383.6150   383.6150   391.3790   380.7800   387.4270     26229400
# 2014-10-02   375.0720   375.0720   385.4970   372.9460   383.9880     21777700
# 2014-10-03   359.5120   359.5120   377.6950   357.8590   375.1810     30901200
# 2014-10-04   328.8660   328.8660   364.4870   325.8860   359.8920     47236500
# 2014-10-05   320.5100   320.5100   341.8010   289.2960   328.9160     83308096
# ...               ...        ...        ...        ...        ...          ...
# 2024-03-08 68300.0938 68300.0938 70083.0547 66230.4531 66938.0938  59202881172
# 2024-03-09 68498.8828 68498.8828 68673.0547 68053.1250 68299.2578  21609650379
# 2024-03-10 69019.7891 69019.7891 70005.2031 68239.9766 68500.2578  35683977532
# 2024-03-11 72123.9062 72123.9062 72850.7109 67194.8828 69020.5469  65716656765
# 2024-03-12 71481.2891 71481.2891 72825.6562 68728.8516 72125.1250  62554434520
#
# ...

# %%
df = df.swaplevel(axis = "columns").sort_index(axis = "columns")
df
# Out:
# Price      Adj Close                                                           \
# Ticker           AMC       BA    BTC-USD EURUSD=X      GC=F     MSFT USDEUR=X
# Date
# 2014-10-01  167.6496 108.4067   383.6150   1.2628 1214.6000  39.3870   0.7919
# 2014-10-02  169.7717 107.9719   375.0720   1.2624 1214.2000  39.2669   0.7921
# 2014-10-03  171.3084 109.8762   359.5120   1.2671 1192.2000  39.5501   0.7892
# 2014-10-04       NaN      NaN   328.8660      NaN       NaN      NaN      NaN
# 2014-10-05       NaN      NaN   320.5100      NaN       NaN      NaN      NaN
# ...              ...      ...        ...      ...       ...      ...      ...
# 2024-03-08    4.3000 198.4900 68300.0938   1.0950 2178.6001 406.2200   0.9132
# 2024-03-09       NaN      NaN 68498.8828      NaN       NaN      NaN      NaN
# 2024-03-10       NaN      NaN 69019.7891      NaN       NaN      NaN      NaN
# 2024-03-11    4.3600 192.4900 72123.9062   1.0943 2182.5000 404.5200   0.9138
# ...

# %%
close = df.Close.copy()
dfCopy = df.copy()
close
# Out:
# Ticker          AMC       BA    BTC-USD  EURUSD=X      GC=F     MSFT  USDEUR=X
# Date
# 2014-10-01 229.1000 124.6700   383.6150    1.2628 1214.6000  45.9000    0.7919
# 2014-10-02 232.0000 124.1700   375.0720    1.2624 1214.2000  45.7600    0.7921
# 2014-10-03 234.1000 126.3600   359.5120    1.2671 1192.2000  46.0900    0.7892
# 2014-10-04      NaN      NaN   328.8660       NaN       NaN      NaN       NaN
# 2014-10-05      NaN      NaN   320.5100       NaN       NaN      NaN       NaN
# ...             ...      ...        ...       ...       ...      ...       ...
# 2024-03-08   4.3000 198.4900 68300.0938    1.0950 2178.6001 406.2200    0.9132
# 2024-03-09      NaN      NaN 68498.8828       NaN       NaN      NaN       NaN
# 2024-03-10      NaN      NaN 69019.7891       NaN       NaN      NaN       NaN
# 2024-03-11   4.3600 192.4900 72123.9062    1.0943 2182.5000 404.5200    0.9138
# 2024-03-12   4.3400 184.2400 71481.2891    1.0931 2160.3999 415.2800    0.9148
#
# ...

# %%
close.describe()
# Out:
# Ticker       AMC        BA    BTC-USD  EURUSD=X      GC=F      MSFT  USDEUR=X
# count  2377.0000 2377.0000  3451.0000 2462.0000 2376.0000 2377.0000 2462.0000
# mean    173.2085  219.5348 15373.4535    1.1258 1518.6373  163.6401    0.8905
# std     116.9193   82.3400 16843.9564    0.0562  306.4259  105.3832    0.0445
# min       3.6700   95.0100   178.1030    0.9596 1050.8000   40.2900    0.7799
# 25%      68.0000  147.8800  1012.5900    1.0884 1245.3500   64.2100    0.8563
# 50%     150.5000  202.7100  8595.7402    1.1208 1396.8500  133.6800    0.8922
# 75%     273.7000  262.0200 26264.5605    1.1679 1815.0750  253.5900    0.9188
# max     625.5000  440.6200 72123.9062    1.2822 2182.5000  420.5500    1.0421

# %%
close.dropna().plot(figsize = (15,8), fontsize = 13) 
#dropna()는 결측값을 제외한다는 것.plot()은 시각화를 수행하는 메서드임다
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ### **Normalizing Financial Time Series to a Base Value (100)**
# ###### 절대 가격으로는 금융 상품의 실적을 비교할 수 없다
# ###### 한가지 해결책은 가격을 정규화 하는 것인데 예를 들어 100이라는 범위를 정해줄 수 있다.

# %%
close
# Out:
# Ticker          AMC       BA    BTC-USD  EURUSD=X      GC=F     MSFT  USDEUR=X
# Date
# 2014-10-01 229.1000 124.6700   383.6150    1.2628 1214.6000  45.9000    0.7919
# 2014-10-02 232.0000 124.1700   375.0720    1.2624 1214.2000  45.7600    0.7921
# 2014-10-03 234.1000 126.3600   359.5120    1.2671 1192.2000  46.0900    0.7892
# 2014-10-04      NaN      NaN   328.8660       NaN       NaN      NaN       NaN
# 2014-10-05      NaN      NaN   320.5100       NaN       NaN      NaN       NaN
# ...             ...      ...        ...       ...       ...      ...       ...
# 2024-03-08   4.3000 198.4900 68300.0938    1.0950 2178.6001 406.2200    0.9132
# 2024-03-09      NaN      NaN 68498.8828       NaN       NaN      NaN       NaN
# 2024-03-10      NaN      NaN 69019.7891       NaN       NaN      NaN       NaN
# 2024-03-11   4.3600 192.4900 72123.9062    1.0943 2182.5000 404.5200    0.9138
# 2024-03-12   4.3400 184.2400 71481.2891    1.0931 2160.3999 415.2800    0.9148
#
# ...

# %%
close.iloc[0,0] #first Price AMC
# Out:
# 229.10000610351562

# %%
close.BA.div(close.iloc[0,0])
# Out:
# Date
# 2014-10-01   0.5442
# 2014-10-02   0.5420
# 2014-10-03   0.5515
# 2014-10-04      NaN
# 2014-10-05      NaN
#               ...
# 2024-03-08   0.8664
# 2024-03-09      NaN
# 2024-03-10      NaN
# 2024-03-11   0.8402
# 2024-03-12   0.8042
# Freq: D, Name: BA, Length: 3451, dtype: float64

# %%
close.iloc[0]
# Out:
# Ticker
# AMC         229.1000
# BA          124.6700
# BTC-USD     383.6150
# EURUSD=X      1.2628
# GC=F       1214.6000
# MSFT         45.9000
# USDEUR=X      0.7919
# Name: 2014-10-01 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[1]).mul(100)
norm
# Out:
# Ticker          AMC       BA    BTC-USD  EURUSD=X     GC=F     MSFT  USDEUR=X
# Date
# 2014-10-01  98.7500 100.4027   102.2777  100.0328 100.0329 100.3060   99.9672
# 2014-10-02 100.0000 100.0000   100.0000  100.0000 100.0000 100.0000  100.0000
# 2014-10-03 100.9052 101.7637    95.8515  100.3674  98.1881 100.7212   99.6339
# 2014-10-04      NaN      NaN    87.6808       NaN      NaN      NaN       NaN
# 2014-10-05      NaN      NaN    85.4529       NaN      NaN      NaN       NaN
# ...             ...      ...        ...       ...      ...      ...       ...
# 2024-03-08   1.8534 159.8534 18209.8625   86.7394 179.4268 887.7186  115.2879
# 2024-03-09      NaN      NaN 18262.8627       NaN      NaN      NaN       NaN
# 2024-03-10      NaN      NaN 18401.7444       NaN      NaN      NaN       NaN
# 2024-03-11   1.8793 155.0213 19229.3501   86.6824 179.7480 884.0035  115.3636
# 2024-03-12   1.8707 148.3772 19058.0184   86.5905 177.9279 907.5175  115.4861
#
# [3451 rows x 7 columns]

# %%
norm.dropna().plot(figsize = (15, 8), fontsize = 13, logy = True)
plt.legend(fontsize = 13)
plt.show()

# %%
close
# Out:
# Ticker          AMC       BA    BTC-USD  EURUSD=X      GC=F     MSFT  USDEUR=X
# Date
# 2014-10-01 229.1000 124.6700   383.6150    1.2628 1214.6000  45.9000    0.7919
# 2014-10-02 232.0000 124.1700   375.0720    1.2624 1214.2000  45.7600    0.7921
# 2014-10-03 234.1000 126.3600   359.5120    1.2671 1192.2000  46.0900    0.7892
# 2014-10-04      NaN      NaN   328.8660       NaN       NaN      NaN       NaN
# 2014-10-05      NaN      NaN   320.5100       NaN       NaN      NaN       NaN
# ...             ...      ...        ...       ...       ...      ...       ...
# 2024-03-08   4.3000 198.4900 68300.0938    1.0950 2178.6001 406.2200    0.9132
# 2024-03-09      NaN      NaN 68498.8828       NaN       NaN      NaN       NaN
# 2024-03-10      NaN      NaN 69019.7891       NaN       NaN      NaN       NaN
# 2024-03-11   4.3600 192.4900 72123.9062    1.0943 2182.5000 404.5200    0.9138
# 2024-03-12   4.3400 184.2400 71481.2891    1.0931 2160.3999 415.2800    0.9148
#
# ...

# %%
close.to_csv("close.csv")
